# %%
import numpy as np
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt

print "Hello world!"

x = np.linspace(0,2*np.pi,100)
y = np.sin(x)

plt.plot(x,y,"k")
plt.savefig("plot.png")
# Out:
# Hello world!
